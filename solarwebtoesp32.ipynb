# %%
# !pip install selenium
# !apt-get update -qq
# !apt install chromium-chromedriver -qq

from urllib.request import urlopen
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options

chrome_options = Options()
chrome_options.add_argument('--headless')
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')

baseURL1 = 'http://api.thingspeak.com/update?api_key=MILC4IHVNMDO2RFB&field1='
baseURL2 = 'http://api.thingspeak.com/update?api_key=C7QQX5QKHX0AHJWL&field1='

contador=0

driver = webdriver.Chrome(options=chrome_options)

driver.get("https://solarweb.com")

time.sleep(32)

cookie_boton=driver.find_element(By.XPATH,'//*[@id="CybotCookiebotDialogBodyLevelButtonLevelOptinAllowAll"]').click()

time.sleep(5)

inicio_boton=driver.find_element(By.XPATH,'/html/body/nav/div/ul[2]/li[1]/a/span').click()

time.sleep(17)

email_casilla=driver.find_element(By.XPATH,'//*[@id="usernameUserInput"]').send_keys('solarwebcel@gmail.com')

time.sleep(2)

pass_casilla=driver.find_element(By.XPATH,'//*[@id="password"]').send_keys('SostreLaCebera')

time.sleep(2)

login_boton=driver.find_element(By.XPATH,'//*[@id="login-button"]').click()

time.sleep(15)

while 1:

  driver.get("https://www.solarweb.com/ActualData/GetCompareDataForPvSystem?pvSystemId=ab52e83c-2600-49b6-b54f-d4a21c7a268d")

  time.sleep(28)

  codigo= driver.page_source

  isonline=codigo.split('"IsOnline":')[1]

  isonline=isonline.split('}')[0]

  if isonline=='false':
      print(isonline)
  else:
      validar=codigo.split('"P_PV":')[1]

      validar=validar.split('}')[0]

      if validar=='null':

           print(validar)

      else:

        potencia=codigo.split('"P_PV":')[1]

        potencia=potencia.split('.')[0]

        urlopen(baseURL1 + potencia)

        print(potencia)

        contador=contador+1

        urlopen(baseURL2 + str(contador))
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 35.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.2/499.2 kB 17.8 MB/s eta 0:00:00
# ...
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# The following additional packages will be installed:
#   apparmor chromium-browser libfuse3-3 libudev1 snapd squashfs-tools
#   systemd-hwe-hwdb udev
# Suggested packages:
#   apparmor-profiles-extra apparmor-utils fuse3 zenity | kdialog
# The following NEW packages will be installed:
#   apparmor chromium-browser chromium-chromedriver libfuse3-3 snapd
#   squashfs-tools systemd-hwe-hwdb udev
# The following packages will be upgraded:
#   libudev1
# 1 upgraded, 8 newly installed, 0 to remove and 36 not upgraded.
# Need to get 30.3 MB of archives.
# After this operation, 123 MB of additional disk space will be used.
# ...
